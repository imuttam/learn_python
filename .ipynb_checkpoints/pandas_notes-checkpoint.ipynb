# %%
import os
import pandas as pd

# %%
data = pd.read_csv('./data_analysis/data_set/car-sales-extended.csv')

# %%
data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
data = './data_analysis/data_set/car-sales-extended.csv'

# %%
data.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
df = pd.read_csv('score.csv')

# %%
df.columns
# Out:
# Index(['CardNo', 'Gender', 'DateOfBirth', 'CityTown', 'Mathematics', 'Physics',
#        'Chemistry', 'Total'],
#       dtype='object')

# %%
df['Mathematics'].mean()
# Out:
# np.float64(72.36666666666666)

# %%
df.iloc[:10,:4]
# Out:
#    CardNo       Name Gender DateOfBirth
# 0       0  Bhuvanesh      M       7 Nov
# 1       1     Harish      M       3 Jun
# 2       2   Shashank      M       4 Jan
# 3       3       Rida      F       5 May
# 4       4     Ritika      F      17 Nov
# 5       5    Akshaya      F       8 Feb
# 6       6     Sameer      M      23 Mar
# 7       7     Aditya      M      15 Mar
# 8       8      Surya      M      28 Feb
# 9       9   Clarence      M       6 Dec

# %%
df.groupby('Gender')['Total'].mean()
# Out:
# Gender
# F    227.076923
# M    218.941176
# Name: Total, dtype: float64

# %%
df.groupby('Gender')['Total'].sum()
# Out:
# Gender
# F    2952
# M    3722
# Name: Total, dtype: int64

# %%
df.groupby('Gender')['Total'].count()
# Out:
# Gender
# F    13
# M    17
# Name: Total, dtype: int64

# %%
df = df[['Name','Physics','Chemistry','Total']]

# %%
df
# Out:
#          Name  Physics  Chemistry  Total
# 0   Bhuvanesh       64         78    210
# 1      Harish       45         91    198
# 2    Shashank       54         77    188
# 3        Rida       53         78    173
# 4      Ritika       64         89    240
# 5     Akshaya       92         84    247
# 6      Sameer       82         87    250
# 7      Aditya       92         76    252
# 8       Surya       64         51    189
# 9    Clarence       88         73    224
# 10      Kavya       72         68    204
# 11      Rahul       92         92    281
# 12   Srinidhi       64         71    187
# 13       Gopi       73         89    227
# 14     Sophia       62         93    244
# 15    Goutami       58         90    224
# 16    Tauseef       86         43    216
# 17     Arshad       81         67    210
# 18    Abirami       92         97    261
# 19   Vetrivel       78         62    196
# 20     Kalyan       68         91    252
# 21     Monika       69         74    221
# ...

# %%
df[(df['Physics']>70) & (df['Chemistry']>80)]
# Out:
#        Name  Physics  Chemistry  Total
# 5   Akshaya       92         84    247
# 6    Sameer       82         87    250
# 11    Rahul       92         92    281
# 13     Gopi       73         89    227
# 18  Abirami       92         97    261
# 23  Deepika       91         88    276
# 25    Geeta       75         92    254
# 26       JK       71         82    227
# 28    Nisha       83         83    240

# %%
df1 = df.set_index('Name')

# %%
df1
# Out:
#            Physics  Chemistry  Total
# Name
# Bhuvanesh       64         78    210
# Harish          45         91    198
# Shashank        54         77    188
# Rida            53         78    173
# Ritika          64         89    240
# Akshaya         92         84    247
# Sameer          82         87    250
# Aditya          92         76    252
# Surya           64         51    189
# Clarence        88         73    224
# Kavya           72         68    204
# Rahul           92         92    281
# Srinidhi        64         71    187
# Gopi            73         89    227
# Sophia          62         93    244
# Goutami         58         90    224
# Tauseef         86         43    216
# Arshad          81         67    210
# Abirami         92         97    261
# Vetrivel        78         62    196
# Kalyan          68         91    252
# Monika          69         74    221
# Priya           62         57    181
# Deepika         91         88    276
# ...

# %%
df1['Physics'].max()
# Out:
# np.int64(92)

# %%
df = pd.read_csv('score.csv')

# %% [markdown]
# ##

# %%
df2 = df[['Name','Mathematics']]
df2 = df2.set_index('Name')

# %%
df3 = pd.concat([df1,df2],axis=1)

# %%
#MERGE 
df4 = df[['Name','Physics']]
df5 = df[['Name','Chemistry']]

# %%
df6 = pd.merge(df4,df5)

# %%
df6.head()
# Out:
#         Name  Physics  Chemistry
# 0  Bhuvanesh       64         78
# 1     Harish       45         91
# 2   Shashank       54         77
# 3       Rida       53         78
# 4     Ritika       64         89

# %%
# Getting marks of Rida,Kavya and Gopi

df_selected = df.loc[['Rida','Kavya'], ['Mathematics','Chemistry','Physics']]
# df_selected.index
df_selected
# Out:
#        Mathematics  Chemistry  Physics
# Name
# Rida            42         78       53
# Kavya           64         68       72

# %%
# other way 
data = pd.read_csv('score.csv')
filtered_df = data[data['Name'].isin(['Rida', 'Kavya', 'Gopi'])]

# %%
filtered_df
# Out:
#     CardNo   Name Gender DateOfBirth CityTown  Mathematics  Physics  \
# 3        3   Rida      F       5 May  Chennai           42       53
# 10      10  Kavya      F      12 Jan  Chennai           64       72
# 13      13   Gopi      M       6 May  Madurai           65       73
#
#     Chemistry  Total
# 3          78    173
# 10         68    204
# 13         89    227

# %%
math_great_90 = data[data['Mathematics'] > 90]
math_great_90
# Out:
#     CardNo     Name Gender DateOfBirth   CityTown  Mathematics  Physics  \
# 11      11    Rahul      M      30 Apr  Bengaluru           97       92
# 20      20   Kalyan      M      17 Sep    Vellore           93       68
# 23      23  Deepika      F      13 May  Bengaluru           97       91
#
#     Chemistry  Total
# 11         92    281
# 20         91    252
# 23         88    276

# %%
#Rida Marks
rida = data[data['Name'] == 'Rida']
rida
# Out:
#    CardNo  Name Gender DateOfBirth CityTown  Mathematics  Physics  Chemistry  \
# 3       3  Rida      F       5 May  Chennai           42       53         78
#
#    Total
# 3    173

# %%
#chennai students
chennai = data[data['CityTown'] == 'Chennai']
chennai = data[data['CityTown'].isin(['Chennai'])]  # takes a list
chennai
# Out:
#     CardNo      Name Gender DateOfBirth CityTown  Mathematics  Physics  \
# 2        2  Shashank      M       4 Jan  Chennai           57       54
# 3        3      Rida      F       5 May  Chennai           42       53
# 5        5   Akshaya      F       8 Feb  Chennai           71       92
# 10      10     Kavya      F      12 Jan  Chennai           64       72
# 12      12  Srinidhi      F      14 Jan  Chennai           52       64
# 17      17    Arshad      M      14 Dec  Chennai           62       81
# 25      25     Geeta      F      16 May  Chennai           87       75
# 26      26        JK      M      22 Jul  Chennai           74       71
#
#     Chemistry  Total
# 2          77    188
# 3          78    173
# 5          84    247
# 10         68    204
# 12         71    187
# 17         67    210
# 25         92    254
# 26         82    227
