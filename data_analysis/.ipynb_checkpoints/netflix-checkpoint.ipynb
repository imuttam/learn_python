# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\Users\\ACER\\Documents\\PYTHON\\data_analysis'

# %%
file_path = 'C:\\Users\\ACER\\Documents\\PYTHON\\data_analysis\\data_set\\netflix_titles.csv'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ACER\\Documents\\PYTHON\\data_analysis\\data_set'

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ***NULl COLUMNS***

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df = df.drop(columns=["show_id","description","date_added",])

# %%
df.head(10)
# Out:
#       type                             title                       director  \
# 0    Movie              Dick Johnson Is Dead                Kirsten Johnson
# 1  TV Show                     Blood & Water                            NaN
# 2  TV Show                         Ganglands                Julien Leclercq
# 3  TV Show             Jailbirds New Orleans                            NaN
# 4  TV Show                      Kota Factory                            NaN
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
# 8  TV Show     The Great British Baking Show                Andy Devonshire
# 9    Movie                      The Starling                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# ...

# %%
netflix_movies = df.loc[df['type'] == 'Movie']

# %%
netflix_movies
# Out:
#        type                             title                       director  \
# 0     Movie              Dick Johnson Is Dead                Kirsten Johnson
# 6     Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7     Movie                           Sankofa                   Haile Gerima
# 9     Movie                      The Starling                 Theodore Melfi
# 12    Movie                      Je Suis Karl            Christian Schwochow
# ...     ...                               ...                            ...
# 8801  Movie                           Zinzana                Majid Al Ansari
# 8802  Movie                            Zodiac                  David Fincher
# 8804  Movie                        Zombieland                Ruben Fleischer
# 8805  Movie                              Zoom                   Peter Hewitt
# 8806  Movie                            Zubaan                    Mozez Singh
#
# ...

# %% [markdown]
# #### LOC WITH AND ####

# %%
netflix_movies_india = df.loc[(df['type'] == 'Movie') & (df['country'] == 'India')]

# %%
netflix_movies_india
# Out:
#        type                  title                 director  \
# 24    Movie                  Jeans               S. Shankar
# 105   Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114   Movie                 Anjaam             Rahul Rawail
# 116   Movie                 Dhanak          Nagesh Kukunoor
# 118   Movie                Gurgaon            Shanker Raman
# ...     ...                    ...                      ...
# 8772  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799  Movie                  Zenda           Avadhoot Gupte
# 8806  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  release_year  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India          1998
# 105   Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India          2017
# ...

# %% [markdown]
# ***FOR MULTIPLE COUNTRY***

# %%
netflix_movies_india = df.loc[(df['type'] == 'Movie') & (df['country'].str.contains('India', na=False))]

# %%
netflix_movies_india
# Out:
#        type                  title                 director  \
# 24    Movie                  Jeans               S. Shankar
# 29    Movie               Paranoia           Robert Luketic
# 105   Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114   Movie                 Anjaam             Rahul Rawail
# 116   Movie                 Dhanak          Nagesh Kukunoor
# ...     ...                    ...                      ...
# 8772  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799  Movie                  Zenda           Avadhoot Gupte
# 8806  Movie                 Zubaan              Mozez Singh
#
#                                                    cast  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 29    Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 105   Antony Varghese, Reshma Rajan, Binny Rinky Ben...
# ...

# %%
movies_vicky_kaushal = netflix_movies_india.loc[netflix_movies_india["cast"].str.contains('Vicky Kaushal', na=False)]

# %%
movies_vicky_kaushal
# Out:
#        type                 title  \
# 1678  Movie      Raman Raghav 2.0
# 4507  Movie                 Sanju
# 4825  Movie          Lust Stories
# 5040  Movie  Love Per Square Foot
# 8806  Movie                Zubaan
#
#                                                director  \
# 1678                                     Anurag Kashyap
# 4507                                    Rajkumar Hirani
# 4825  Zoya Akhtar, Karan Johar, Anurag Kashyap, Diba...
# 5040                                       Anand Tiwari
# 8806                                        Mozez Singh
#
#                                                    cast country  release_year  \
# 1678  Nawazuddin Siddiqui, Vicky Kaushal, Sobhita Dh...   India          2016
# 4507  Ranbir Kapoor, Vicky Kaushal, Paresh Rawal, So...   India          2018
# 4825  Vicky Kaushal, Bhumi Pednekar, Radhika Apte, N...   India          2018
# 5040  Vicky Kaushal, Angira Dhar, Alankrita Sahai, R...   India          2018
# ...

# %%
movies_anurag = df.loc[df["director"].str.contains('Anurag Kashyap', na=False)]

# %%
movies_anurag
# Out:
#          type                    title  \
# 1673    Movie             Black Friday
# 1678    Movie         Raman Raghav 2.0
# 2267    Movie           Bombay Talkies
# 2420    Movie  Choked: Paisa Bolta Hai
# 3060    Movie            Ghost Stories
# 3589  TV Show             Sacred Games
# 4562    Movie                    Dev.D
# 4825    Movie             Lust Stories
# 8652    Movie                     Ugly
#
#                                                director  \
# 1673                                     Anurag Kashyap
# 1678                                     Anurag Kashyap
# 2267  Anurag Kashyap, Dibakar Banerjee, Karan Johar,...
# 2420                                     Anurag Kashyap
# 3060  Anurag Kashyap, Dibakar Banerjee, Karan Johar,...
# 3589               Vikramaditya Motwane, Anurag Kashyap
# 4562                                     Anurag Kashyap
# 4825  Zoya Akhtar, Karan Johar, Anurag Kashyap, Diba...
# 8652                                     Anurag Kashyap
#
# ...

# %%
thriller = df.loc[df['listed_in'].str.contains('Thriller', na=False)]

# %%
thriller
# Out:
#          type                           title         director  \
# 18      Movie                       Intrusion       Adam Salky
# 29      Movie                        Paranoia   Robert Luketic
# 33    TV Show                      Squid Game              NaN
# 35      Movie  The Father Who Moves Mountains     Daniel Sandu
# 42      Movie                          Jaws 2   Jeannot Szwarc
# ...       ...                             ...              ...
# 8733    Movie                    White Island  Benjamin Turner
# 8749  TV Show                      Winter Sun              NaN
# 8760    Movie                Would You Rather   David Guy Levy
# 8801    Movie                         Zinzana  Majid Al Ansari
# 8802    Movie                          Zodiac    David Fincher
#
#                                                    cast  \
# 18    Freida Pinto, Logan Marshall-Green, Robert Joh...
# 29    Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# ...

# %%
movies_thriller = df.loc[(df['listed_in'].str.contains('Thriller', na=False)) & (df['type'] == 'Movie')]

# %%
movies_thriller
# Out:
#        type                           title         director  \
# 18    Movie                       Intrusion       Adam Salky
# 29    Movie                        Paranoia   Robert Luketic
# 35    Movie  The Father Who Moves Mountains     Daniel Sandu
# 42    Movie                          Jaws 2   Jeannot Szwarc
# 43    Movie                          Jaws 3        Joe Alves
# ...     ...                             ...              ...
# 8732  Movie                   White Chamber     Paul Raschid
# 8733  Movie                    White Island  Benjamin Turner
# 8760  Movie                Would You Rather   David Guy Levy
# 8801  Movie                         Zinzana  Majid Al Ansari
# 8802  Movie                          Zodiac    David Fincher
#
#                                                    cast  \
# 18    Freida Pinto, Logan Marshall-Green, Robert Joh...
# 29    Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 35    Adrian Titieni, Elena Purea, Judith State, Val...
# ...

# %%
movies_thriller_year = df.loc[(df['listed_in'].str.contains('Thriller', na=False)) & (df['type'] == 'Movie')& (df['release_year']>2020)]

# %%
movies_thriller_year
# Out:
#        type                           title  \
# 18    Movie                       Intrusion
# 35    Movie  The Father Who Moves Mountains
# 86    Movie                            Prey
# 236   Movie                         Boomika
# 237   Movie                 Boomika (Hindi)
# 238   Movie             Boomika (Malayalam)
# 239   Movie                Boomika (Telugu)
# 252   Movie                    Black Island
# 363   Movie                       The Vault
# 384   Movie                   Hostage House
# 398   Movie     Kingdom: Ashin of the North
# 439   Movie                            Deep
# 485   Movie                     Lethal Love
# 551   Movie                 Haseen Dillruba
# 556   Movie                   The 8th Night
# 624   Movie                      Prime Time
# 711   Movie                        Security
# 746   Movie                           Awake
# 836   Movie                       Ghost Lab
# 878   Movie                           Ferry
# ...
